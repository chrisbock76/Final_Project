# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Merge data sets

# %%
file = "NPX_data1.xlsx"
df = pd.read_excel(file, skiprows=1)

# %%
df_cleaned = df.set_index("NPX Data")

# %%
#Drop null value rows
df_cleaned = df_cleaned.dropna(how='all')
df_cleaned
# Out:
#                                Unnamed: 1             Unnamed: 2  \
# NPX Data
# Panel               Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# Assay                                CHL1                   NRP1
# Uniprot ID                         O00533                 O14786
# OlinkID                          OID01216               OID01217
# A1                                12.9561                3.72971
# ...                                   ...                    ...
# B77                               9.97518                8.55345
# B78                               12.8194                6.10399
# B79                               10.5029                8.93464
# LOD                               2.36847                0.15632
# Missing Data freq.                0.01875                0.01875
#
#                                Unnamed: 3             Unnamed: 4  \
# NPX Data
# Panel               Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# ...

# %%
df_cleaned = df_cleaned.iloc[:,0:1104]
df_cleaned
# Out:
#                                Unnamed: 1             Unnamed: 2  \
# NPX Data
# Panel               Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# Assay                                CHL1                   NRP1
# Uniprot ID                         O00533                 O14786
# OlinkID                          OID01216               OID01217
# A1                                12.9561                3.72971
# ...                                   ...                    ...
# B77                               9.97518                8.55345
# B78                               12.8194                6.10399
# B79                               10.5029                8.93464
# LOD                               2.36847                0.15632
# Missing Data freq.                0.01875                0.01875
#
#                                Unnamed: 3             Unnamed: 4  \
# NPX Data
# Panel               Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# ...

# %%
col_len = len(df_cleaned.columns)
for x in range(col_len):
    df_cleaned.iloc[1][x] = f'{df_cleaned.iloc[1][x]}-{df_cleaned.iloc[3][x]}'
df_cleaned
# Out:
#                                Unnamed: 1             Unnamed: 2  \
# NPX Data
# Panel               Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# Assay                       CHL1-OID01216          NRP1-OID01217
# Uniprot ID                         O00533                 O14786
# OlinkID                          OID01216               OID01217
# A1                                12.9561                3.72971
# ...                                   ...                    ...
# B77                               9.97518                8.55345
# B78                               12.8194                6.10399
# B79                               10.5029                8.93464
# LOD                               2.36847                0.15632
# Missing Data freq.                0.01875                0.01875
#
#                                Unnamed: 3             Unnamed: 4  \
# NPX Data
# Panel               Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# ...

# %%
#Reset Index Values
df_cleaned = df_cleaned.reset_index()
#Rename column to SampleID for later merge
df_cleaned = df_cleaned.rename(columns={"NPX Data":"SampleID"})
df_cleaned
# Out:
#                SampleID             Unnamed: 1             Unnamed: 2  \
# 0                 Panel  Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# 1                 Assay          CHL1-OID01216          NRP1-OID01217
# 2            Uniprot ID                 O00533                 O14786
# 3               OlinkID               OID01216               OID01217
# 4                    A1                12.9561                3.72971
# ..                  ...                    ...                    ...
# 161                 B77                9.97518                8.55345
# 162                 B78                12.8194                6.10399
# 163                 B79                10.5029                8.93464
# 164                 LOD                2.36847                0.15632
# 165  Missing Data freq.                0.01875                0.01875
#
#                 Unnamed: 3             Unnamed: 4             Unnamed: 5  \
# ...

# %%
#Drop unnecessary data rows
df_cleaned = df_cleaned.drop([2,3,164,165])
df_cleaned = df_cleaned.reset_index(drop=True)

# %%
df_cleaned
# Out:
#     SampleID             Unnamed: 1             Unnamed: 2  \
# 0      Panel  Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# 1      Assay          CHL1-OID01216          NRP1-OID01217
# 2         A1                12.9561                3.72971
# 3         A2                11.2695                 6.1448
# 4         A3                25.4511                6.95051
# ..       ...                    ...                    ...
# 157      B75                13.0247                3.91889
# 158      B76                12.6518                  9.768
# 159      B77                9.97518                8.55345
# 160      B78                12.8194                6.10399
# 161      B79                10.5029                8.93464
#
#                 Unnamed: 3             Unnamed: 4             Unnamed: 5  \
# 0    Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# 1          PLXNB2-OID01218        FCGR3B-OID01219        LILRB5-OID01220
# ...

# %%
#Make new dataframe using Uniprot ID as headers
headers=df_cleaned.iloc[1]
new_df = pd.DataFrame(df_cleaned.values, columns=headers)
new_df.columns
# Out:
# Index(['Assay', 'CHL1-OID01216', 'NRP1-OID01217', 'PLXNB2-OID01218',
#        'FCGR3B-OID01219', 'LILRB5-OID01220', 'APOM-OID01221', 'SOD1-OID01222',
#        'CA1-OID01223', 'TIMP1-OID01224',
#        ...
#        'RRM2B-OID01111', 'PTK7-OID01112', 'PVALB-OID01113', 'EGFL7-OID01114',
#        'FABP9-OID01115', 'TMPRSS15-OID01116', 'LHB-OID01117', 'FOSB-OID01118',
#        'CALR-OID01119', 'PGF-OID01493'],
#       dtype='object', name=1, length=1105)

# %%
new_df= new_df.reset_index(drop=True)

# %%
new_df
# Out:
# 1    Assay          CHL1-OID01216          NRP1-OID01217  \
# 0    Panel  Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# 1    Assay          CHL1-OID01216          NRP1-OID01217
# 2       A1                12.9561                3.72971
# 3       A2                11.2695                 6.1448
# 4       A3                25.4511                6.95051
# ..     ...                    ...                    ...
# 157    B75                13.0247                3.91889
# 158    B76                12.6518                  9.768
# 159    B77                9.97518                8.55345
# 160    B78                12.8194                6.10399
# 161    B79                10.5029                8.93464
#
# 1          PLXNB2-OID01218        FCGR3B-OID01219        LILRB5-OID01220  \
# 0    Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# 1          PLXNB2-OID01218        FCGR3B-OID01219        LILRB5-OID01220
# ...

# %%
#Rename and set the index to the Samples column
new_df = new_df.rename(columns={"Assay":"SampleID"})
new_df = new_df.drop([0,1])
new_df = new_df.set_index("SampleID")

# %%
new_df
# Out:
# 1        CHL1-OID01216 NRP1-OID01217 PLXNB2-OID01218 FCGR3B-OID01219  \
# SampleID
# A1             12.9561       3.72971         2.08612         11.6096
# A2             11.2695        6.1448         1.48398         17.5821
# A3             25.4511       6.95051         1.22821         10.4949
# A4              14.453       3.72539         3.27885         14.9697
# A5             7.62871       7.19834         4.98903         13.0875
# ...                ...           ...             ...             ...
# B75            13.0247       3.91889         3.16333         11.9611
# B76            12.6518         9.768         3.26224         14.7462
# B77            9.97518       8.55345         4.28095         9.93514
# B78            12.8194       6.10399         3.61861         5.40553
# B79            10.5029       8.93464         3.10352         15.2554
#
# 1        LILRB5-OID01220 APOM-OID01221 SOD1-OID01222 CA1-OID01223  \
# SampleID
# ...

# %%
#Read sample info data excel to dataframe
info_df = pd.read_excel("NPX_data1_info.xlsx")

info_df.head()
# Out:
#   SampleID Subject  Treatment    Site      Time   Project
# 0       A1     ID1  Untreated  Site_D  Baseline  20200001
# 1       A2     ID1  Untreated  Site_D    Week.6  20200001
# 2       A3     ID1  Untreated  Site_D   Week.12  20200001
# 3       A4     ID2  Untreated  Site_C  Baseline  20200001
# 4       A5     ID2  Untreated  Site_C    Week.6  20200001

# %%
#Merge dataframes together on SampleID
merged_df = new_df.merge(info_df, on="SampleID", how="inner")
merged_df
# Out:
#     SampleID CHL1-OID01216 NRP1-OID01217 PLXNB2-OID01218 FCGR3B-OID01219  \
# 0         A1       12.9561       3.72971         2.08612         11.6096
# 1         A2       11.2695        6.1448         1.48398         17.5821
# 2         A3       25.4511       6.95051         1.22821         10.4949
# 3         A4        14.453       3.72539         3.27885         14.9697
# 4         A5       7.62871       7.19834         4.98903         13.0875
# ..       ...           ...           ...             ...             ...
# 151      B75       13.0247       3.91889         3.16333         11.9611
# 152      B76       12.6518         9.768         3.26224         14.7462
# 153      B77       9.97518       8.55345         4.28095         9.93514
# 154      B78       12.8194       6.10399         3.61861         5.40553
# 155      B79       10.5029       8.93464         3.10352         15.2554
#
#     LILRB5-OID01220 APOM-OID01221 SOD1-OID01222 CA1-OID01223 TIMP1-OID01224  \
# ...

# %%
merged_df = merged_df.drop(columns=["Project"])

# %%
#Save data to CSV
merged_df.to_csv("Resources/NPX_data1_merged.csv", index=False)

# %%
merged_df = pd.read_csv("Resources/NPX_data1_merged.csv")

# %%
#Make dataframes for the different timeframes of data
baseline_df = merged_df.loc[merged_df['Time']=="Baseline"]
week6_df = merged_df.loc[merged_df['Time']=="Week.6"]
week12_df = merged_df.loc[merged_df['Time']=="Week.12"]
baseline_df
# Out:
#     SampleID     O00533     O14786    O15031     O75015     O75023     O95445  \
# 0         A1  12.956143   3.729709  2.086122  11.609629   0.724192   8.542624
# 3         A4  14.453038   3.725393  3.278853  14.969670   1.132330  16.194933
# 6         A7  12.730612  10.802000  1.187524   7.963439  -0.293644   6.786595
# 9        A10  12.258445   5.226161  3.325876   7.520732   7.384593  16.361272
# 12       A13   7.748904  11.580115  1.228873   6.120314   1.619912  12.977033
# 15       A16  11.431302  10.207661  3.311984  10.313994   3.526815  13.334769
# 18       A19   7.256171  10.815281  2.211937  -0.214706   4.026527  10.211327
# 21       A22  14.413956   4.499181  2.157865  11.475391   5.275544   8.329090
# 24       A25  10.202038   5.979814  3.677052   3.848114   2.602968  11.658940
# 27       A28  14.298536   9.245159  3.876550  17.613731   1.442955  19.111726
# 30       A31   8.997277   6.213137  4.177450  12.263095   2.457417  14.995332
# ...

# %%
baseline_siteA_df = baseline_df.loc[baseline_df['Site']=="Site_A"]
baseline_siteB_df = baseline_df.loc[baseline_df['Site']=="Site_B"]
baseline_siteC_df = baseline_df.loc[baseline_df['Site']=="Site_C"]
baseline_siteD_df = baseline_df.loc[baseline_df['Site']=="Site_D"]
baseline_siteE_df = baseline_df.loc[baseline_df['Site']=="Site_E"]

# %%
baseline_df.groupby(baseline_df["Site"]).describe()
# Out:
#        O00533                                                                  \
#         count       mean       std       min        25%        50%        75%
# Site
# Site_A    8.0   8.801686  5.006175  1.961005   5.570681   9.376870  13.400164
# Site_B   11.0  11.547921  3.371398  6.154775   9.242052  12.258445  13.539416
# Site_C   11.0   9.687707  2.853650  5.908104   7.391639   9.772788  11.439175
# Site_D   10.0  11.130493  3.092461  4.468631  10.676456  11.963578  12.899760
# Site_E   12.0   9.727063  3.555468  2.957737   6.991745   9.844470  12.529023
#
#                   O14786            ...     P27797            P49763-3  \
#               max  count      mean  ...        75%        max    count
# Site                                ...
# Site_A  13.888386    8.0  5.329042  ...  10.693028  12.033291      8.0
# Site_B  17.299621   11.0  6.442782  ...  10.669754  12.760318     11.0
# Site_C  14.453038   11.0  5.386173  ...   9.405562  17.592489     11.0
# ...

# %%
baseline_siteA_df
# Out:
#     SampleID     O00533    O14786    O15031     O75015    O75023     O95445  \
# 78        B2   7.573612  2.522189  2.655571  15.020350  5.672701  14.499941
# 84        B8  13.268125  3.540364  4.965877  16.466069  1.279578  14.371421
# 90       B14  13.888386  3.697425  3.095572  13.735469  0.198667   7.382163
# 99       B23   6.768384  8.414718  2.772149   4.482868 -2.833513  13.518468
# 102      B26   1.977572  4.552043  3.417100   5.719547  6.632924   7.210487
# 120      B44  13.796280  9.569685  2.110575  20.969224  5.458884   8.408252
# 126      B50  11.180128  5.815551  4.737795   7.211828  3.816469   2.340093
# 150      B74   1.961005  4.520364  4.933749   1.658025  4.319246  13.785119
#
#         P00441    P00915    P01033  ...     Q0Z7S8    P98073    P01229  \
# 78    5.679460  3.803006  3.406612  ...   7.981480  2.560009  2.205397
# 84    8.539138  4.887639  3.365334  ...   6.689667 -1.274897  2.040864
# ...

# %% [markdown]
# ## Make scatter plots

# %%
#Assign X values as the Sample IDs
bx1 = baseline_siteA_df.iloc[:,0]
bx2 = baseline_siteB_df.iloc[:,0]
bx3 = baseline_siteC_df.iloc[:,0]
bx4 = baseline_siteD_df.iloc[:,0]
bx5 = baseline_siteE_df.iloc[:,0]

# #Set the Y values for the first protein ID from the different timeframe DFs
# by1 = baseline_df.iloc[:,1:1105].astype(float)
# by2 = baseline_siteB_df.iloc[:,1:1104].astype(float)
# by3 = baseline_siteC_df.iloc[:,1:1104].astype(float)
# by4 = baseline_siteD_df.iloc[:,1:1104].astype(float)
# by5 = baseline_siteE_df.iloc[:,1:1104].astype(float)
# print(bx1.shape, by1.shape, by2.shape, by3.shape, by4.shape, by5.shape)

#Assign X values as the Sample IDs
#bx1 = baseline_df.iloc[:,0]

#Set the Y values for the first protein ID from the different timeframe DFs
by1 = baseline_siteA_df.iloc[:,1].astype(float)
by2 = baseline_siteB_df.iloc[:,1].astype(float)
by3 = baseline_siteC_df.iloc[:,1].astype(float)
by4 = baseline_siteD_df.iloc[:,1].astype(float)
by5 = baseline_siteE_df.iloc[:,1].astype(float)

print(bx1.shape, by1.shape, by2.shape, by3.shape,by4.shape,by5.shape)
# Out:
# (8,) (8,) (11,) (11,) (10,) (12,)

# %%
print(bx1.values)
print(by1.values)
print(by2.values)
print(by3.values)
# Out:
# ['A1' 'A4' 'A7' 'A10' 'A13' 'A16' 'A19' 'A22' 'A25' 'A28' 'A31' 'A34'
#  'A37' 'A40' 'A43' 'A46' 'A49' 'A52' 'A55' 'A58' 'A61' 'A64' 'A67' 'A70'
#  'A73' 'A76' 'B2' 'B5' 'B8' 'B11' 'B14' 'B17' 'B20' 'B23' 'B26' 'B29'
#  'B32' 'B35' 'B38' 'B41' 'B44' 'B47' 'B50' 'B53' 'B56' 'B59' 'B62' 'B65'
#  'B68' 'B71' 'B74' 'B77']
# [12.95614259 14.4530382  12.73061157 12.25844521  7.74890398 11.43130242
#   7.25617099 14.41395639 10.20203845 14.29853556  8.99727684 10.52831186
#  12.49585426  6.15477467 13.23990328 11.55884667  9.48690094 10.70655956
#  13.90306073 17.29962067 12.41925541 10.44290829 13.68295263  9.77278808
#   4.46863118 12.85832412  7.57361235  2.95773712 13.26812506 11.12088694
#  13.88838572 15.18093419  6.08913168  6.7683838   1.97757165  5.90810382
#   7.06813398 13.39587933 12.17179131  7.21176362 13.79628023 12.84634126
#  11.18012779  7.82867149  6.73638105 14.54734963  8.69789032  7.57151533
#   6.7625767   9.78621417  1.96100482  9.9751778 ]
# ...

# %%
#Make a scatter plot for the first protein
plt.scatter(bx1, by1, c='r', s=20,label="Site A")
plt.scatter(bx2, by2, c='g', s=20,label="Site B")
plt.scatter(bx3, by3, c='b', s=20,label="Site C")
plt.scatter(bx4, by4, c='purple', s=20,label="Site D")
plt.scatter(bx5, by5, c='orange', s=20,label="Site E")
plt.legend(['Site A','Site B','Site C','Site D','Site E'])
plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0)
plt.title("Baseline NPX of Protein O00553 by Sites")
plt.xlabel("Sample ID")
plt.xticks(rotation=90)
plt.ylabel("NPX")
plt.savefig("Site_Samples.png")
