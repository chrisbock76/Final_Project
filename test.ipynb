# %%
import pandas as pd
import os 
import csv
import matplotlib.pyplot as plt

# %%
file = "NPX_data1.xlsx"

# %%
df = pd.read_excel(file, skiprows=1)

# %%
df
# Out:
#                NPX Data             Unnamed: 1             Unnamed: 2  \
# 0                 Panel  Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# 1                 Assay                   CHL1                   NRP1
# 2            Uniprot ID                 O00533                 O14786
# 3               OlinkID               OID01216               OID01217
# 4                   NaN                    NaN                    NaN
# ..                  ...                    ...                    ...
# 163                 B78                12.8194                6.10399
# 164                 B79                10.5029                8.93464
# 165                 NaN                    NaN                    NaN
# 166                 LOD                2.36847                0.15632
# 167  Missing Data freq.                0.01875                0.01875
#
#                 Unnamed: 3             Unnamed: 4             Unnamed: 5  \
# ...

# %%
df_indexed = df.set_index("NPX Data")

# %%
df_indexed.head()
# Out:
#                        Unnamed: 1             Unnamed: 2  \
# NPX Data
# Panel       Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# Assay                        CHL1                   NRP1
# Uniprot ID                 O00533                 O14786
# OlinkID                  OID01216               OID01217
# NaN                           NaN                    NaN
#
#                        Unnamed: 3             Unnamed: 4  \
# NPX Data
# Panel       Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# Assay                      PLXNB2                 FCGR3B
# Uniprot ID                 O15031                 O75015
# OlinkID                  OID01218               OID01219
# NaN                           NaN                    NaN
#
#                        Unnamed: 5             Unnamed: 6  \
# NPX Data
# Panel       Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# Assay                      LILRB5                   APOM
# Uniprot ID                 O75023                 O95445
# ...

# %%
df_cleaned = df_indexed.iloc[:, 0:1104]
col_len = len(df_cleaned.columns)

# %%
df_cleaned
# Out:
#                                Unnamed: 1             Unnamed: 2  \
# NPX Data
# Panel               Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# Assay                                CHL1                   NRP1
# Uniprot ID                         O00533                 O14786
# OlinkID                          OID01216               OID01217
# NaN                                   NaN                    NaN
# ...                                   ...                    ...
# B78                               12.8194                6.10399
# B79                               10.5029                8.93464
# NaN                                   NaN                    NaN
# LOD                               2.36847                0.15632
# Missing Data freq.                0.01875                0.01875
#
#                                Unnamed: 3             Unnamed: 4  \
# NPX Data
# Panel               Olink CARDIOMETABOLIC  Olink CARDIOMETABOLIC
# ...

# %%
df_noNull = df_cleaned.dropna()

# %%
df_noNull
# Out:
#                          Unnamed: 1       Unnamed: 2       Unnamed: 3  \
# NPX Data
# Panel               CARDIOMETABOLIC  CARDIOMETABOLIC  CARDIOMETABOLIC
# Assay                          CHL1             NRP1           PLXNB2
# OlinkID                    OID01216         OID01217         OID01218
# A1                          12.9561          3.72971          2.08612
# A2                          11.2695           6.1448          1.48398
# ...                             ...              ...              ...
# B77                         9.97518          8.55345          4.28095
# B78                         12.8194          6.10399          3.61861
# B79                         10.5029          8.93464          3.10352
# LOD                         2.36847          0.15632         0.260781
# Missing Data freq.          0.01875          0.01875          0.01875
#
#                          Unnamed: 4       Unnamed: 5       Unnamed: 6  \
# NPX Data
# ...

# %%
col_len
# Out:
# 1104

# %%
for x in range(col_len):
    df_cleaned.iloc[0][x] = df_cleaned.iloc[0][x].split("Olink ")[1]

# %%
type_of_panels = int(col_len / 92)
# Out:
# 12

# %%
by_types_arr = []
a = 0
i = 92
m = 92
for y in range(type_of_panels):
    panel = df_cleaned.iloc[0,a]
    panel_type = df_cleaned.iloc[:,a:i]
    by_types_arr.append(panel_type)
    a = a + m
    i = i + m
    panel_type.to_csv(f'Resources/data1_{panel}.csv')

# %%
df_cleaned.iloc[0,194]
# Out:
# 'CARDIOVASCULAR III'

# %%
df_cleaned.iloc[0,92]
# Out:
# 'CARDIOVASCULAR II'

# %%
if df_cleaned.iloc[0,91] == df_cleaned.iloc[0,(91+1)]:
    print(df_cleaned.iloc[0,0])

# %%
sample_df = df.iloc[0:19, 0:1105]

# %%
sample_df = sample_df.set_index("Unnamed: 0")

# %%
sample_df
# Out:
#              Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                    A1   12.956143    3.729709    2.086122   11.609629
# 1                    A2   11.269477    6.144801    1.483985   17.582141
# 2                    A3   25.451070    6.950510    1.228214   10.494904
# 3                    A4   14.453038    3.725393    3.278853   14.969670
# 4                    A5    7.628712    7.198343    4.989030   13.087540
# 5                    A6    6.316586    7.789239    4.654764   11.463464
# 6                    A7   12.730612   10.802000    1.187524    7.963439
# 7                    A8   13.666335    9.878969    0.690800    0.115430
# 8   CONTROL_SAMPLE_AS 1   16.196824    3.616462    2.747751   15.624112
# 9                    A9    6.106562    4.504996    1.549334   -0.807968
# 10                  A10   12.258445    5.226161    3.325876    7.520732
# 11                  A11   10.676396   13.319587    4.494698   12.652505
# ...

# %%
sample_df_no_control = sample_df.drop(8)

# %%
sample_df_no_control
# Out:
#    Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          A1   12.956143    3.729709    2.086122   11.609629    0.724192
# 1          A2   11.269477    6.144801    1.483985   17.582141    3.329488
# 2          A3   25.451070    6.950510    1.228214   10.494904    4.392219
# 3          A4   14.453038    3.725393    3.278853   14.969670    1.132330
# 4          A5    7.628712    7.198343    4.989030   13.087540    1.237068
# 5          A6    6.316586    7.789239    4.654764   11.463464    2.342279
# 6          A7   12.730612   10.802000    1.187524    7.963439   -0.293644
# 7          A8   13.666335    9.878969    0.690800    0.115430    1.800357
# 9          A9    6.106562    4.504996    1.549334   -0.807968    3.447811
# 10        A10   12.258445    5.226161    3.325876    7.520732    7.384593
# 11        A11   10.676396   13.319587    4.494698   12.652505    6.675573
# 12        A12   16.514964    9.654317    4.086087    8.149456    6.093130
# ...

# %%
baseline = sample_df_no_control.iloc[[0, 3, 6, 9, 12, 15]]
week6 = sample_df_no_control.iloc[[1, 4, 7, 10, 13, 16]]
week12 = sample_df_no_control.iloc[[2, 5, 8, 11, 14, 17]]
sub1 = sample_df_no_control.iloc[0:3]

# %%
sub1 = sub1.set_index("Unnamed: 0")

# %%
x1 = sub1.columns
y1 = sub1.iloc[0]
y2 = sub1.iloc[1]
y3 = sub1.iloc[2]

# %%
print(x1.shape, y.shape)
# Out:
# (1104,) (1104,)

# %%
plt.plot(x1, y1, 'b', x1, y2, "g", x1, y3, "r")
#plt.plot(x1, y2, "g")
#plt.plot(x1, y3, "r")
plt.legend(('BaseLine', '6 Weeks', '12 Weeks'))
plt.savefig("sample1.png")

# %%
baseline = baseline.set_index("Unnamed: 0")

# %%
baseline
# Out:
#             Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# Unnamed: 0
# A1           12.956143    3.729709    2.086122   11.609629    0.724192
# A4           14.453038    3.725393    3.278853   14.969670    1.132330
# A7           12.730612   10.802000    1.187524    7.963439   -0.293644
# A10          12.258445    5.226161    3.325876    7.520732    7.384593
# A13           7.748904   11.580115    1.228873    6.120314    1.619912
# A16          11.431302   10.207661    3.311984   10.313994    3.526815
#
#             Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  ...  \
# Unnamed: 0                                                               ...
# A1            8.542624    9.452978    7.795929    3.116308    12.019284  ...
# A4           16.194933   12.066842   -0.580701    4.565457    10.029911  ...
# A7            6.786595   16.286984    1.116435    1.436761    11.486912  ...
# ...

# %%
bx1 = baseline.columns
by1 = baseline.iloc[0]
by2 = baseline.iloc[1]
by3 = baseline.iloc[2]
by4 = baseline.iloc[3]
by5 = baseline.iloc[4]
by6 = baseline.iloc[5]
print(bx1.shape, by1.shape, by2.shape, by3.shape, by4.shape, by5.shape, by6.shape)
# Out:
# (1104,) (1104,) (1104,) (1104,) (1104,) (1104,) (1104,)

# %%
plt.scatter(bx1, by1, c='r', s=0.2)
plt.scatter(bx1, by2, c='b', s=0.2)
plt.scatter(bx1, by3, c='y', s=0.2)
plt.scatter(bx1, by4, c='g', s=0.2)
plt.scatter(bx1, by5, c='m', s=0.2)
plt.scatter(bx1, by6, c='c', s=0.2)
##plt.scatter(bx1, by1, 'b', by2, "g", bx1, by3, "r", 
#bx1, by4, "w", bx1, by5, "b", bx1, by6, "y")
plt.legend(('Sub1', 'Sub2', 'Sub3', 'Sub4', 'Sub5', 'Sub6'))
plt.savefig("Week6_sample.png")

# %%
cardiometabolic_df = pd.read_csv("Resources/data1_CARDIOMETABOLIC.csv", skiprows=3)

# %%
cardiometabolic_df_cleaned = cardiometabolic_df.dropna()
cardiometabolic_df_cleaned = cardiometabolic_df_cleaned.rename(columns={"Uniprot ID":"SampleID"})

# %%
cardiometabolic_df_cleaned
# Out:
#                SampleID            O00533             O14786  \
# 0               OlinkID          OID01216           OID01217
# 2                    A1  12.9561425886431   3.72970924582771
# 3                    A2   11.269476531342   6.14480091936497
# 4                    A3  25.4510701414362   6.95051017310168
# 5                    A4  14.4530382024394   3.72539338198674
# ..                  ...               ...                ...
# 159                 B77  9.97517780474675     8.553448820892
# 160                 B78  12.8193632173862   6.10398500763625
# 161                 B79   10.502865019702   8.93464138028839
# 163                 LOD  2.36846658156787  0.156320288637653
# 164  Missing Data freq.           0.01875            0.01875
#
#                O15031            O75015             O75023            O95445  \
# 0            OID01218          OID01219           OID01220          OID01221
# ...

# %%
cardiometabolic_df_cleaned = cardiometabolic_df_cleaned.set_index("SampleID")

# %%
cardiometabolic_df_dropped = cardiometabolic_df_cleaned.drop(["OlinkID", "CONTROL_SAMPLE_AS 1", "CONTROL_SAMPLE_AS 2", "LOD", "Missing Data freq."])

# %%
cardiometabolic_df_dropped
# Out:
#                     O00533            O14786            O15031  \
# SampleID
# A1        12.9561425886431  3.72970924582771  2.08612231436114
# A2         11.269476531342  6.14480091936497  1.48398497994593
# A3        25.4510701414362  6.95051017310168  1.22821356879884
# A4        14.4530382024394  3.72539338198674  3.27885288239876
# A5         7.6287118351486  7.19834323864719  4.98902951047932
# ...                    ...               ...               ...
# B75       13.0246883750201  3.91888614752226  3.16333408940248
# B76       12.6518356746632  9.76799840102501  3.26223878260669
# B77       9.97517780474675    8.553448820892  4.28094686656499
# B78       12.8193632173862  6.10398500763625  3.61861105798951
# B79        10.502865019702  8.93464138028839  3.10352376464103
#
#                     O75015             O75023            O95445  \
# SampleID
# A1         11.609629003747  0.724191555213795  8.54262355014331
# ...

# %%
sampleID = cardiometabolic_df_dropped.index
baseline_sam = []
week6_sam = []
week12_sam = []

# %%
sample_num = len(sampleID)

# %%
b = 0
s = 1
t = 2
for m in range(int(sample_num/3)):
    baseline_sam.append(sampleID[b])
    week6_sam.append(sampleID[s])
    week12_sam.append(sampleID[t])
    b = b + 3
    s = s + 3
    t = t + 3

# %%
cardiometabolic_df_dropped.loc[baseline_sam[0]]
# Out:
# O00533     12.9561425886431
# O14786     3.72970924582771
# O15031     2.08612231436114
# O75015      11.609629003747
# O75023    0.724191555213795
#                 ...
# Q9H1U4     1.73558169216479
# Q9NQ79     8.11764000083775
# Q9UGM5     3.51787177260598
# Q9Y5C1     9.47575616239197
# Q9Y5Y7     5.86528636644432
# Name: A1, Length: 92, dtype: object
