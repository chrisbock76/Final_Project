# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create dummy data
from sklearn.datasets.samples_generator import make_blobs

X, _ = make_blobs(n_samples=500, centers=6,
                            cluster_std=0.70, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-68f78c8bcd29> in <module>
#       4 X, _ = make_blobs(n_samples=500, centers=6,
#       5                             cluster_std=0.70, random_state=0)
# ----> 6 X.shape()
#
# TypeError: 'tuple' object is not callable

# %%
# Plot and show scatter
plt.scatter(X[:, 0], X[:, 1])
plt.show()

# %%
# Create a kmeans model using k = 12
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=12)

# Fit the model to the data
kmeans.fit(X)

# Use the data to predict the clusters
# save the predictions as `predicted_clusters`
predicted_clusters = kmeans.predict(X)

# %%
# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], c=predicted_clusters, s=50, cmap='viridis')
plt.show()

# %%
# Print the cluster centers and cluster labels
centers = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
centers
# Out:
# array([[-1.03037126,  3.30291155],
#        [ 9.13807392, -1.74292256],
#        [-1.73645868,  7.31571802],
#        [ 6.17080098,  0.11008676],
#        [ 0.98776867,  3.68467213],
#        [ 0.92668189,  4.88657398],
#        [ 2.36828576,  0.18703832],
#        [ 5.55427337,  1.11228788],
#        [ 1.75804641,  1.18009529],
#        [ 9.39564555, -2.8498309 ],
#        [-1.03103707,  8.21383008],
#        [-2.0371292 ,  2.39357843]])

# %%
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)

plt.show()
